# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>Melisa Miranda Fredes</b><br>
# Data science

# %% [markdown]
# <i> Estoy interesda en ciencia de datos porque me apasionada utilizar la estadística para aplicar conocimientos a problemas de la vida
# real y poder contribuir a mejorar la eficiencia </i>

# %% [markdown]
# <h3>El codigo descrito debajo hara la suma de una mas uno arrojando dos como resultado</h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <ul>
# <li>1</li>
# <li>2</li>
# <li>3</li>
# </ul>
#
# <hr>
#
# <table>
# <tr>
#   <td><strong>Curso</strong></td>
#   <td><strong>Horas</strong></td>
#   <td><strong>Horario</strong></td>
# </tr>
#
# <tr>
#   <td>CSS</td>
#   <td>20</td>
#   <td>16:00 - 20:00</td>
# </tr>
#
# <tr>
#   <td>HTML</td>
#   <td>20</td>
#   <td>16:00 - 20:00</td>
# </tr>
#
# <tr>
#   <td>Dreamweaver</td>
#   <td>60</td>
#   <td>16:00 - 20:00</td>
# </tr>
# </table>
